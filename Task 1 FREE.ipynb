# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data", "Science", "Mentorship", "Program", "started", "By", "CampusX", sep = "-")
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
celsius = int(input("Enter celsius - "))
print("Farhenheit is ",(celsius * 9/5) + 32)
# Out:
# Farhenheit is  89.6

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
num1 = int(input("Enter number 1"))
num2 = int(input("Enter number 2"))

temp = num1

num1 = num2
num2 = temp

print("Num 1:" , num1 , "and Num 2: ", num2)
# Out:
# Num 1  34 and Num 2 23

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
x1 = int(input("Enter x1: "))
y1 = int(input("Enter y1: "))

x2 = int(input("Enter x2: "))
y2 = int(input("Enter y2: "))

x = (x2 - x1) ** 2
y = (y2 - y1) ** 2

distance = (x + y) ** 0.5

print("The Euclidean distance is:", distance)
# Out:
# The Euclidean distance is: 5.0

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
principle = int(input("Enter initial amount"))
rate = int(input("Enter rate of intrest"))
time = int(input("Enter time in years"))

result = (principle * rate * time) / 100

print("Simple Intrest :", result)
# Out:
# Simple Intrest : 100.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
head = int(input("Enter heads :"))
legs = int(input("Enter legs :"))

dogs = (legs - (2 * head)) // 2
chicken = ((4 * head) - legs) // 2

print("Dogs are :" , dogs, "Chickens are :",chicken)
# Out:
# Dogs are : 2 Chickens are : 2

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
n = int(input("Enter a num: "))

result = n * (n + 1) * (2 * n + 1) / 6

print("Sum of square of First n Natural Num:", result)
# Out:
# Sum of square of First n Natural Num: 14.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
a1 = int(input("Enter first number : "))
a2 = int(input("Enter second number : "))

n = int(input("Enter Position : "))

diffrence = a2 - a1

result = a1 + ( n - 1 ) * diffrence

print(" the Nth term is :" , result)
# Out:
#  the Nth term is : 11

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
n1 = int(input("Enter n1: "))
d1 = int(input("Enter d1: "))
n2 = int(input("Enter n2: "))
d2 = int(input("Enter d2: "))

numerator = (n1 * d2) + (n2 * d1)
denominator = d1 * d2

print("Sum of two fractions is:", numerator, "/", denominator)
# Out:
# Sum of two fractions is: 10 / 8

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
L = float(input("Enter Length of tank (cm): "))
B = float(input("Enter Breadth of tank (cm): "))
H = float(input("Enter Height of tank (cm): "))

r = float(input("Enter Radius of glass (cm): "))
h = float(input("Enter Height of glass (cm): "))

tank_volume = L * B * H
glass_volume = 3.14 * r * r * h

glasses = tank_volume / glass_volume

print("Number of glasses that can be filled:", int(glasses))
# Out:
# Number of glasses that can be filled: 849
